# %% [markdown]
# # Fast ASR Data Cleaning Pass (QASR + Casablanca + Omnilingual)
#
# This notebook performs the **same fast first-pass cleaning** as the base notebook, but it only targets these datasets:
#
# - `processed_qasr_segments`
# - `casablanca_jordanian`
# - `casablanca_palestinian`
# - `omnilingual_apc`
#
# It keeps the same cleaning behavior:
#
# - Drop transcripts containing English letters.
# - Drop transcripts containing numbers.
# - Report transcripts containing bracket/angle tokens like `[laugh]` or `<noise>`, but **keep them**.
# - Drop rows with `duration < 0.5s` using the existing duration metadata.
# - Create `manual_normalized_transcript`.
# - Write dropped rows into folders named by reason.
# - Write per-dataset and global reports.
#
# It does **not**:
#
# - Decode audio.
# - Check RMS/silence.
# - Check corrupt audio.
# - Resample audio.
# - Convert mono/stereo.
# - Perform PCM or loudness normalization.
#
# Those audio safeguards should happen defensively inside the training loader/collator.

# %% [markdown]
# ## 0. Optional environment setup
#
# Run this in a terminal if the environment does not already have the required packages.
#
# ```bash
# cd /home/MohammadNabulsi/whisper
#
# python -m venv .venv
# source .venv/bin/activate
#
# pip install -U pip
# pip install pandas pyarrow tqdm
# ```

# %%
from pathlib import Path
import json
import re
import unicodedata
import hashlib
import shutil
import time
from collections import Counter, defaultdict

import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
from tqdm.auto import tqdm

print("Imports ready.")
# Out:
# Imports ready.

# %% [markdown]
# ## 1. Configuration
#
# Change only these paths if needed.
#
# For your current VM layout, the defaults assume:
#
# ```text
# /home/MohammadNabulsi/whisper/data
# ```
#
# as the shared data root, and then select only:
#
# - `processed_qasr_segments/train/*.arrow`
# - `casablanca_jordanian/*.parquet`
# - `casablanca_palestinian/*.parquet`
# - `omnilingual_apc/data-*.arrow`
#
# This intentionally skips QASR index JSONL files and Omnilingual cache Arrow files.

# %%
# =========================
# Main paths
# =========================

INPUT_ROOT = Path("/home/MohammadNabulsi/whisper/data")
OUTPUT_ROOT = Path("/home/MohammadNabulsi/whisper/data_cleaned_text_qasr_casablanca_omni_v1")

# Target only the requested datasets.
# This keeps the cleaning logic identical while avoiding obvious
# non-training artifacts like QASR index JSONL files and HF cache Arrow files.
DISCOVERY_GLOBS = [
    "processed_qasr_segments/train/*.arrow",
    "casablanca_jordanian/*.parquet",
    "casablanca_palestinian/*.parquet",
    "omnilingual_apc/data-*.arrow",
]

# =========================
# Cleaning behavior
# =========================

MIN_DURATION_SEC = 0.5
BATCH_SIZE = 20_000
LOG_EVERY_ROWS = 50_000
COMPRESSION = "zstd"

# If True, output folder is deleted before running.
OVERWRITE_OUTPUT = True

# If set to an integer, only process the first N discovered files.
# Use this for a tiny test first, e.g. DRY_RUN_MAX_FILES = 2
DRY_RUN_MAX_FILES = None

# If duration column is missing, we cannot apply the <0.5s rule without decoding.
# Recommended for fast pass: keep rows with missing duration but report them.
DROP_MISSING_DURATION = False

TEXT_COLUMN_CANDIDATES = [
    "transcript",
    "transcription",
    "text",
    "raw_text",
    "sentence",
    "normalized_text",
]

DURATION_COLUMN_CANDIDATES = [
    "duration",
    "duration_sec",
    "duration_seconds",
    "audio_duration",
    "length_sec",
]

DATASET_COLUMN_CANDIDATES = [
    "dataset",
    "source",
    "corpus",
    "config",
    "dialect",
    "language",
]

print("INPUT_ROOT:", INPUT_ROOT)
print("OUTPUT_ROOT:", OUTPUT_ROOT)
print("DISCOVERY_GLOBS:")
for pat in DISCOVERY_GLOBS:
    print(" -", pat)
# Out:
# INPUT_ROOT: /home/MohammadNabulsi/whisper/data
# OUTPUT_ROOT: /home/MohammadNabulsi/whisper/data_cleaned_text_qasr_casablanca_omni_v1
# DISCOVERY_GLOBS:
#  - processed_qasr_segments/train/*.arrow
#  - casablanca_jordanian/*.parquet
#  - casablanca_palestinian/*.parquet
#  - omnilingual_apc/data-*.arrow

# %% [markdown]
# ## 2. Text detection and normalization functions

# %%
ENGLISH_RE = re.compile(r"[A-Za-z]")
NUMBER_RE = re.compile(r"[0-9٠-٩۰-۹]")
BRACKET_RE = re.compile(r"(\[[^\]]+\]|<[^>]+>)")

DIACRITICS_RE = re.compile(
    r"[\u0610-\u061A\u064B-\u065F\u0670\u06D6-\u06ED]"
)

TATWEEL = "\u0640"

ALEF_VARIANTS = {
    "أ": "ا",
    "إ": "ا",
    "آ": "ا",
    "ٱ": "ا",
}

ARABIC_PUNCT_EXTRA = "،؛؟"


def normalize_arabic_transcript(text) -> str:
    """
    Manual ASR transcript normalization:
    - NFKC Unicode normalization
    - Alef variants -> bare alef
    - remove diacritics
    - remove punctuation
    - remove tatweel
    - collapse whitespace
    """
    if text is None:
        return ""

    text = str(text)
    text = unicodedata.normalize("NFKC", text)

    for src, dst in ALEF_VARIANTS.items():
        text = text.replace(src, dst)

    text = text.replace(TATWEEL, "")
    text = DIACRITICS_RE.sub("", text)

    out = []
    for ch in text:
        cat = unicodedata.category(ch)
        if cat.startswith("P") or ch in ARABIC_PUNCT_EXTRA:
            out.append(" ")
        else:
            out.append(ch)

    text = "".join(out)
    text = re.sub(r"\s+", " ", text).strip()
    return text


def has_english(text) -> bool:
    return bool(ENGLISH_RE.search("" if text is None else str(text)))


def has_number(text) -> bool:
    return bool(NUMBER_RE.search("" if text is None else str(text)))


def has_bracket_token(text) -> bool:
    return bool(BRACKET_RE.search("" if text is None else str(text)))


# Tiny sanity check
examples = [
    "أكلتُ التفاحةَ، وقال: آهـــ!",
    "مرحبا [laugh] كيفك؟",
    "test عربي",
    "عندي ٣ كتب",
]

for x in examples:
    print("RAW :", x)
    print("NORM:", normalize_arabic_transcript(x))
    print("english:", has_english(x), "number:", has_number(x), "bracket:", has_bracket_token(x))
    print()
# Out:
# RAW : أكلتُ التفاحةَ، وقال: آهـــ!
# NORM: اكلت التفاحة وقال اه
# english: False number: False bracket: False
#
# RAW : مرحبا [laugh] كيفك؟
# NORM: مرحبا laugh كيفك
# english: True number: False bracket: True
#
# RAW : test عربي
# NORM: test عربي
# english: True number: False bracket: False
#
# RAW : عندي ٣ كتب
# NORM: عندي ٣ كتب
# english: False number: True bracket: False

# %% [markdown]
# ## 3. Helper functions
#
# The notebook writes parquet shards like:
#
# ```text
# data_cleaned_text_v1/
# ├── clean/
# │   └── <input-file-id>__clean.parquet
# ├── dropped/
# │   ├── contains_english/
# │   │   └── <input-file-id>__dropped.parquet
# │   ├── contains_number/
# │   │   └── <input-file-id>__dropped.parquet
# │   ├── audio_too_short/
# │   │   └── <input-file-id>__dropped.parquet
# │   └── missing_duration/
# │       └── <input-file-id>__dropped.parquet
# └── reports/
#     ├── cleaning_report.json
#     ├── per_dataset_report.csv
#     └── run_manifest.json
# ```

# %%
def log(msg: str):
    ts = time.strftime("%Y-%m-%d %H:%M:%S")
    line = f"[{ts}] {msg}"
    print(line)
    if "REPORTS_DIR" in globals():
        REPORTS_DIR.mkdir(parents=True, exist_ok=True)
        with (REPORTS_DIR / "run.log").open("a", encoding="utf-8") as f:
            f.write(line + "\n")


def find_first_column(schema_names, candidates):
    names = set(schema_names)
    for col in candidates:
        if col in names:
            return col
    return None


def safe_float(x):
    if x is None:
        return None
    try:
        if pd.isna(x):
            return None
    except Exception:
        pass
    try:
        return float(x)
    except Exception:
        return None


def dataset_from_file(path: Path) -> str:
    """
    Fallback dataset name when no dataset/source/corpus/config column exists.
    Uses the closest parent folder name.
    """
    try:
        rel = path.relative_to(INPUT_ROOT)
        if len(rel.parts) >= 2:
            return rel.parts[0]
    except Exception:
        pass
    return path.parent.name or "unknown"


def stable_file_id(path: Path) -> str:
    try:
        rel = str(path.relative_to(INPUT_ROOT))
    except Exception:
        rel = str(path)
    h = hashlib.md5(rel.encode("utf-8")).hexdigest()[:10]
    slug = re.sub(r"[^A-Za-z0-9_.-]+", "_", rel.replace("/", "__"))
    return f"{slug}__{h}"


class TableShardWriter:
    """
    Lazily opens ParquetWriter objects and appends tables.
    Keeps one writer per shard path.
    """
    def __init__(self, compression="zstd"):
        self.compression = compression
        self.writers = {}

    def write(self, path: Path, table: pa.Table):
        if table is None or table.num_rows == 0:
            return

        path.parent.mkdir(parents=True, exist_ok=True)

        key = str(path)
        if key not in self.writers:
            self.writers[key] = pq.ParquetWriter(
                where=path,
                schema=table.schema,
                compression=self.compression,
                use_dictionary=True,
            )

        self.writers[key].write_table(table)

    def close(self):
        for writer in self.writers.values():
            writer.close()
        self.writers.clear()


def add_or_replace_column(table: pa.Table, name: str, values, pa_type=pa.string()):
    arr = pa.array(values, type=pa_type)
    if name in table.column_names:
        idx = table.column_names.index(name)
        return table.set_column(idx, name, arr)
    return table.append_column(name, arr)


def counter_to_percent(n, d):
    return float(n) / float(d) * 100.0 if d else 0.0

# %% [markdown]
# ## 4. Discover input files
#
# This notebook only scans the requested dataset shards via explicit glob patterns, so it excludes:
#
# - `processed_qasr_segments/index/*.jsonl`
# - `omnilingual_apc/cache-*.arrow`
#
# Everything else about the cleaner stays the same.

# %%
pattern_matches = {}
input_files = []

for pattern in DISCOVERY_GLOBS:
    matches = sorted(INPUT_ROOT.glob(pattern))
    pattern_matches[pattern] = matches
    input_files.extend(matches)

# Preserve discovery order while removing accidental duplicates.
input_files = list(dict.fromkeys(input_files))

if DRY_RUN_MAX_FILES is not None:
    input_files = input_files[:DRY_RUN_MAX_FILES]

parquet_files = [p for p in input_files if p.suffix == ".parquet"]
arrow_files = [p for p in input_files if p.suffix == ".arrow"]
jsonl_files = [p for p in input_files if p.suffix == ".jsonl"]

print("Discovery summary:")
for pattern, matches in pattern_matches.items():
    print(f"- {pattern}: {len(matches):,} file(s)")

print(f"Found parquet files: {len(parquet_files):,}")
print(f"Found arrow files  : {len(arrow_files):,}")
print(f"Found jsonl files  : {len(jsonl_files):,}")
print(f"Will process files : {len(input_files):,}")

for p in input_files[:10]:
    print("-", p)

if not input_files:
    raise FileNotFoundError(
        "No .parquet, .arrow, or .jsonl files matched DISCOVERY_GLOBS under "
        f"{INPUT_ROOT}"
    )
# Out:
# Discovery summary:
# - processed_qasr_segments/train/*.arrow: 309 file(s)
# - casablanca_jordanian/*.parquet: 2 file(s)
# - casablanca_palestinian/*.parquet: 4 file(s)
# - omnilingual_apc/data-*.arrow: 3 file(s)
# Found parquet files: 6
# Found arrow files  : 312
# Found jsonl files  : 0
# Will process files : 318
# - /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000000.arrow
# - /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000001.arrow
# - /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000002.arrow
# - /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000003.arrow
# - /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000004.arrow
# - /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000005.arrow
# - /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000006.arrow
# - /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000007.arrow
# - /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000008.arrow
# - /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000009.arrow

# %% [markdown]
# ## 5. Main cleaning function
#
# Drop priority:
#
# 1. `contains_english`
# 2. `contains_number`
# 3. `audio_too_short`
# 4. `missing_duration`, only if `DROP_MISSING_DURATION=True`
#
# Percentages for English, numbers, and bracket tokens are counted independently, even if a row is dropped for another reason.

# %%
def process_table_batch(
    table: pa.Table,
    source_file: Path,
    clean_path: Path,
    dropped_base_dir: Path,
    writer: TableShardWriter,
    totals: Counter,
    per_dataset: dict,
):
    schema_names = table.column_names

    text_col = find_first_column(schema_names, TEXT_COLUMN_CANDIDATES)
    duration_col = find_first_column(schema_names, DURATION_COLUMN_CANDIDATES)
    dataset_col = find_first_column(schema_names, DATASET_COLUMN_CANDIDATES)

    n = table.num_rows
    if n == 0:
        return

    if text_col is None:
        # No transcript means unusable for ASR fine-tuning.
        reason = "missing_transcript"
        source_file_col = [str(source_file)] * n
        table2 = add_or_replace_column(table, "source_file", source_file_col)
        writer.write(dropped_base_dir / reason / f"{stable_file_id(source_file)}__dropped.parquet", table2)

        totals["total"] += n
        totals[f"dropped_{reason}"] += n
        fallback_dataset = dataset_from_file(source_file)
        per_dataset[fallback_dataset]["total"] += n
        per_dataset[fallback_dataset][f"dropped_{reason}"] += n
        return

    text_values = table[text_col].to_pylist()

    if duration_col is not None:
        duration_values = table[duration_col].to_pylist()
    else:
        duration_values = [None] * n

    if dataset_col is not None:
        dataset_values = table[dataset_col].to_pylist()
        dataset_values = [
            str(x) if x is not None and str(x).strip() else dataset_from_file(source_file)
            for x in dataset_values
        ]
    else:
        fallback_dataset = dataset_from_file(source_file)
        dataset_values = [fallback_dataset] * n

    normalized = []
    english_flags = []
    number_flags = []
    bracket_flags = []
    too_short_flags = []
    missing_duration_flags = []
    drop_reasons = []
    keep_mask = []

    for text, dur_raw in zip(text_values, duration_values):
        norm = normalize_arabic_transcript(text)
        eng = has_english(text)
        num = has_number(text)
        bracket = has_bracket_token(text)

        dur = safe_float(dur_raw)
        missing_dur = dur is None
        too_short = False if missing_dur else dur < MIN_DURATION_SEC

        reason = None
        if eng:
            reason = "contains_english"
        elif num:
            reason = "contains_number"
        elif too_short:
            reason = "audio_too_short"
        elif missing_dur and DROP_MISSING_DURATION:
            reason = "missing_duration"

        normalized.append(norm)
        english_flags.append(eng)
        number_flags.append(num)
        bracket_flags.append(bracket)
        too_short_flags.append(too_short)
        missing_duration_flags.append(missing_dur)
        drop_reasons.append(reason)
        keep_mask.append(reason is None)

    table = add_or_replace_column(table, "manual_normalized_transcript", normalized, pa.string())
    table = add_or_replace_column(table, "source_file", [str(source_file)] * n, pa.string())

    # Optional useful audit flags.
    table = add_or_replace_column(table, "flag_contains_bracket_token", bracket_flags, pa.bool_())
    table = add_or_replace_column(table, "flag_contains_english", english_flags, pa.bool_())
    table = add_or_replace_column(table, "flag_contains_number", number_flags, pa.bool_())
    table = add_or_replace_column(table, "flag_audio_too_short", too_short_flags, pa.bool_())
    table = add_or_replace_column(table, "flag_missing_duration", missing_duration_flags, pa.bool_())

    # Counters
    for ds, eng, num, bracket, short, missing_dur, reason in zip(
        dataset_values,
        english_flags,
        number_flags,
        bracket_flags,
        too_short_flags,
        missing_duration_flags,
        drop_reasons,
    ):
        totals["total"] += 1
        per_dataset[ds]["total"] += 1

        if eng:
            totals["contains_english"] += 1
            per_dataset[ds]["contains_english"] += 1

        if num:
            totals["contains_number"] += 1
            per_dataset[ds]["contains_number"] += 1

        if bracket:
            totals["contains_bracket_token"] += 1
            per_dataset[ds]["contains_bracket_token"] += 1

        if short:
            totals["audio_too_short"] += 1
            per_dataset[ds]["audio_too_short"] += 1

        if missing_dur:
            totals["missing_duration"] += 1
            per_dataset[ds]["missing_duration"] += 1

        if reason is None:
            totals["kept"] += 1
            per_dataset[ds]["kept"] += 1
        else:
            totals[f"dropped_{reason}"] += 1
            per_dataset[ds][f"dropped_{reason}"] += 1

    # Write kept rows.
    clean_table = table.filter(pa.array(keep_mask, type=pa.bool_()))
    writer.write(clean_path, clean_table)

    # Write dropped rows by reason.
    unique_reasons = sorted({r for r in drop_reasons if r is not None})
    for reason in unique_reasons:
        mask = [r == reason for r in drop_reasons]
        dropped_table = table.filter(pa.array(mask, type=pa.bool_()))
        dropped_path = dropped_base_dir / reason / f"{stable_file_id(source_file)}__dropped.parquet"
        writer.write(dropped_path, dropped_table)


def iter_parquet_batches(path: Path):
    pf = pq.ParquetFile(path)
    for batch in pf.iter_batches(batch_size=BATCH_SIZE):
        yield pa.Table.from_batches([batch])


def iter_arrow_batches(path: Path):
    """
    Reads Hugging Face / Apache Arrow IPC files.

    Tries file format first, then stream format.
    This avoids decoding audio and only reads the Arrow rows/batches.
    """
    try:
        with pa.memory_map(str(path), "r") as source:
            reader = pa.ipc.open_file(source)
            for i in range(reader.num_record_batches):
                yield pa.Table.from_batches([reader.get_batch(i)])
        return
    except Exception:
        pass

    with pa.memory_map(str(path), "r") as source:
        reader = pa.ipc.open_stream(source)
        for batch in reader:
            yield pa.Table.from_batches([batch])


def iter_jsonl_batches(path: Path):
    # JSONL support is included, but parquet/arrow is preferred for your large ASR data.
    rows = []
    with path.open("r", encoding="utf-8") as f:
        for line in f:
            if line.strip():
                rows.append(json.loads(line))
            if len(rows) >= BATCH_SIZE:
                yield pa.Table.from_pylist(rows)
                rows = []
    if rows:
        yield pa.Table.from_pylist(rows)

# %% [markdown]
# ## 6. Run cleaning
#
# This cell performs the actual cleaning.
#
# For a tiny test first, set:
#
# ```python
# DRY_RUN_MAX_FILES = 2
# OUTPUT_ROOT = Path("/home/MohammadNabulsi/whisper/data_cleaned_text_qasr_casablanca_omni_test")
# ```
#
# Then rerun from the config cell.

# %%
CLEAN_DIR = OUTPUT_ROOT / "clean"
DROPPED_DIR = OUTPUT_ROOT / "dropped"
REPORTS_DIR = OUTPUT_ROOT / "reports"

if OVERWRITE_OUTPUT and OUTPUT_ROOT.exists():
    shutil.rmtree(OUTPUT_ROOT)

CLEAN_DIR.mkdir(parents=True, exist_ok=True)
DROPPED_DIR.mkdir(parents=True, exist_ok=True)
REPORTS_DIR.mkdir(parents=True, exist_ok=True)

config = {
    "input_root": str(INPUT_ROOT),
    "discovery_globs": DISCOVERY_GLOBS,
    "output_root": str(OUTPUT_ROOT),
    "min_duration_sec": MIN_DURATION_SEC,
    "batch_size": BATCH_SIZE,
    "compression": COMPRESSION,
    "drop_missing_duration": DROP_MISSING_DURATION,
    "text_column_candidates": TEXT_COLUMN_CANDIDATES,
    "duration_column_candidates": DURATION_COLUMN_CANDIDATES,
    "dataset_column_candidates": DATASET_COLUMN_CANDIDATES,
    "skipped_audio_decoding": True,
    "skipped_rms_check": True,
    "skipped_resampling": True,
    "skipped_audio_normalization": True,
}
(REPORTS_DIR / "config.json").write_text(json.dumps(config, indent=2, ensure_ascii=False), encoding="utf-8")

totals = Counter()
per_dataset = defaultdict(Counter)

writer = TableShardWriter(compression=COMPRESSION)

processed_since_log = 0
last_total = 0
start_time = time.time()

log("START cleaning")
log(f"Input files: {len(input_files):,}")
log(f"Output root: {OUTPUT_ROOT}")

try:
    for file_idx, path in enumerate(tqdm(input_files, desc="Files"), start=1):
        file_id = stable_file_id(path)
        clean_path = CLEAN_DIR / f"{file_id}__clean.parquet"

        log(f"FILE {file_idx:,}/{len(input_files):,}: {path}")

        if path.suffix == ".parquet":
            batch_iter = iter_parquet_batches(path)
        elif path.suffix == ".arrow":
            batch_iter = iter_arrow_batches(path)
        elif path.suffix == ".jsonl":
            batch_iter = iter_jsonl_batches(path)
        else:
            continue

        for table in batch_iter:
            process_table_batch(
                table=table,
                source_file=path,
                clean_path=clean_path,
                dropped_base_dir=DROPPED_DIR,
                writer=writer,
                totals=totals,
                per_dataset=per_dataset,
            )

            processed_since_log = totals["total"] - last_total
            if processed_since_log >= LOG_EVERY_ROWS:
                elapsed = time.time() - start_time
                rows_per_sec = totals["total"] / max(elapsed, 1e-9)
                dropped = totals["total"] - totals["kept"]
                log(
                    f"PROGRESS rows={totals['total']:,} "
                    f"kept={totals['kept']:,} "
                    f"dropped={dropped:,} "
                    f"rows/sec={rows_per_sec:,.1f}"
                )
                last_total = totals["total"]

finally:
    writer.close()

elapsed = time.time() - start_time
log(f"DONE rows={totals['total']:,} elapsed_min={elapsed/60:.2f}")
print(dict(totals))
# Out:
# [2026-06-26 14:46:44] START cleaning
# [2026-06-26 14:46:44] Input files: 318
# [2026-06-26 14:46:44] Output root: /home/MohammadNabulsi/whisper/data_cleaned_text_qasr_casablanca_omni_v1
# Files:   0%|          | 0/318 [00:00<?, ?it/s]
# [2026-06-26 14:46:44] FILE 1/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000000.arrow
# [2026-06-26 14:46:48] FILE 2/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000001.arrow
# [2026-06-26 14:46:50] FILE 3/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000002.arrow
# [2026-06-26 14:46:52] FILE 4/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000003.arrow
# [2026-06-26 14:46:54] FILE 5/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000004.arrow
# [2026-06-26 14:46:56] FILE 6/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000005.arrow
# [2026-06-26 14:46:58] FILE 7/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000006.arrow
# [2026-06-26 14:47:00] FILE 8/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000007.arrow
# [2026-06-26 14:47:02] FILE 9/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000008.arrow
# [2026-06-26 14:47:06] FILE 10/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000009.arrow
# [2026-06-26 14:47:10] FILE 11/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000010.arrow
# [2026-06-26 14:47:13] FILE 12/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000011.arrow
# [2026-06-26 14:47:17] FILE 13/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000012.arrow
# [2026-06-26 14:47:20] PROGRESS rows=50,608 kept=47,773 dropped=2,835 rows/sec=1,414.0
# [2026-06-26 14:47:20] FILE 14/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000013.arrow
# [2026-06-26 14:47:23] FILE 15/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000014.arrow
# [2026-06-26 14:47:27] FILE 16/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000015.arrow
# [2026-06-26 14:47:28] FILE 17/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000016.arrow
# [2026-06-26 14:47:30] FILE 18/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000017.arrow
# [2026-06-26 14:47:32] FILE 19/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000018.arrow
# [2026-06-26 14:47:34] FILE 20/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000019.arrow
# [2026-06-26 14:47:36] FILE 21/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000020.arrow
# [2026-06-26 14:47:38] FILE 22/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000021.arrow
# [2026-06-26 14:47:40] FILE 23/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000022.arrow
# [2026-06-26 14:47:42] FILE 24/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000023.arrow
# [2026-06-26 14:47:44] FILE 25/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000024.arrow
# [2026-06-26 14:47:46] FILE 26/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000025.arrow
# [2026-06-26 14:47:48] PROGRESS rows=101,488 kept=96,002 dropped=5,486 rows/sec=1,599.9
# [2026-06-26 14:47:48] FILE 27/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000026.arrow
# [2026-06-26 14:47:49] FILE 28/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000027.arrow
# [2026-06-26 14:47:51] FILE 29/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000028.arrow
# [2026-06-26 14:47:53] FILE 30/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000029.arrow
# [2026-06-26 14:47:55] FILE 31/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000030.arrow
# [2026-06-26 14:47:57] FILE 32/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000031.arrow
# [2026-06-26 14:47:59] FILE 33/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000032.arrow
# [2026-06-26 14:48:01] FILE 34/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000033.arrow
# [2026-06-26 14:48:03] FILE 35/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000034.arrow
# [2026-06-26 14:48:04] FILE 36/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000035.arrow
# [2026-06-26 14:48:06] FILE 37/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000036.arrow
# [2026-06-26 14:48:08] FILE 38/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000037.arrow
# [2026-06-26 14:48:10] FILE 39/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000038.arrow
# [2026-06-26 14:48:12] PROGRESS rows=151,762 kept=143,314 dropped=8,448 rows/sec=1,732.8
# [2026-06-26 14:48:12] FILE 40/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000039.arrow
# [2026-06-26 14:48:14] FILE 41/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000040.arrow
# [2026-06-26 14:48:15] FILE 42/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000041.arrow
# [2026-06-26 14:48:17] FILE 43/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000042.arrow
# [2026-06-26 14:48:19] FILE 44/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000043.arrow
# [2026-06-26 14:48:21] FILE 45/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000044.arrow
# [2026-06-26 14:48:23] FILE 46/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000045.arrow
# [2026-06-26 14:48:25] FILE 47/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000046.arrow
# [2026-06-26 14:48:28] FILE 48/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000047.arrow
# [2026-06-26 14:48:31] FILE 49/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000048.arrow
# [2026-06-26 14:48:35] FILE 50/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000049.arrow
# [2026-06-26 14:48:38] FILE 51/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000050.arrow
# [2026-06-26 14:48:42] FILE 52/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000051.arrow
# [2026-06-26 14:48:45] PROGRESS rows=203,664 kept=191,994 dropped=11,670 rows/sec=1,683.0
# [2026-06-26 14:48:45] FILE 53/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000052.arrow
# [2026-06-26 14:48:48] FILE 54/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000053.arrow
# [2026-06-26 14:48:50] FILE 55/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000054.arrow
# [2026-06-26 14:48:54] FILE 56/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000055.arrow
# [2026-06-26 14:48:57] FILE 57/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000056.arrow
# [2026-06-26 14:49:01] FILE 58/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000057.arrow
# [2026-06-26 14:49:04] FILE 59/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000058.arrow
# [2026-06-26 14:49:08] FILE 60/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000059.arrow
# [2026-06-26 14:49:11] FILE 61/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000060.arrow
# [2026-06-26 14:49:13] FILE 62/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000061.arrow
# [2026-06-26 14:49:17] FILE 63/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000062.arrow
# [2026-06-26 14:49:20] FILE 64/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000063.arrow
# [2026-06-26 14:49:24] FILE 65/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000064.arrow
# [2026-06-26 14:49:27] PROGRESS rows=253,730 kept=238,972 dropped=14,758 rows/sec=1,556.9
# [2026-06-26 14:49:27] FILE 66/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000065.arrow
# [2026-06-26 14:49:30] FILE 67/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000066.arrow
# [2026-06-26 14:49:34] FILE 68/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000067.arrow
# [2026-06-26 14:49:36] FILE 69/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000068.arrow
# [2026-06-26 14:49:40] FILE 70/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000069.arrow
# [2026-06-26 14:49:44] FILE 71/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000070.arrow
# [2026-06-26 14:49:47] FILE 72/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000071.arrow
# [2026-06-26 14:49:50] FILE 73/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000072.arrow
# [2026-06-26 14:49:54] FILE 74/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000073.arrow
# [2026-06-26 14:49:57] FILE 75/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000074.arrow
# [2026-06-26 14:50:00] FILE 76/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000075.arrow
# [2026-06-26 14:50:04] FILE 77/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000076.arrow
# [2026-06-26 14:50:08] FILE 78/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000077.arrow
# [2026-06-26 14:50:11] FILE 79/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000078.arrow
# [2026-06-26 14:50:15] PROGRESS rows=307,210 kept=289,142 dropped=18,068 rows/sec=1,458.8
# [2026-06-26 14:50:15] FILE 80/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000079.arrow
# [2026-06-26 14:50:18] FILE 81/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000080.arrow
# [2026-06-26 14:50:20] FILE 82/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000081.arrow
# [2026-06-26 14:50:22] FILE 83/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000082.arrow
# [2026-06-26 14:50:24] FILE 84/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000083.arrow
# [2026-06-26 14:50:26] FILE 85/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000084.arrow
# [2026-06-26 14:50:28] FILE 86/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000085.arrow
# [2026-06-26 14:50:32] FILE 87/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000086.arrow
# [2026-06-26 14:50:36] FILE 88/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000087.arrow
# [2026-06-26 14:50:40] FILE 89/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000088.arrow
# [2026-06-26 14:50:43] FILE 90/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000089.arrow
# [2026-06-26 14:50:47] FILE 91/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000090.arrow
# [2026-06-26 14:50:50] FILE 92/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000091.arrow
# [2026-06-26 14:50:54] FILE 93/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000092.arrow
# [2026-06-26 14:50:58] PROGRESS rows=360,226 kept=339,062 dropped=21,164 rows/sec=1,419.0
# [2026-06-26 14:50:58] FILE 94/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000093.arrow
# [2026-06-26 14:51:02] FILE 95/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000094.arrow
# [2026-06-26 14:51:06] FILE 96/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000095.arrow
# [2026-06-26 14:51:09] FILE 97/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000096.arrow
# [2026-06-26 14:51:13] FILE 98/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000097.arrow
# [2026-06-26 14:51:17] FILE 99/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000098.arrow
# [2026-06-26 14:51:21] FILE 100/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000099.arrow
# [2026-06-26 14:51:24] FILE 101/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000100.arrow
# [2026-06-26 14:51:28] FILE 102/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000101.arrow
# [2026-06-26 14:51:32] FILE 103/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000102.arrow
# [2026-06-26 14:51:36] FILE 104/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000103.arrow
# [2026-06-26 14:51:40] FILE 105/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000104.arrow
# [2026-06-26 14:51:43] FILE 106/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000105.arrow
# [2026-06-26 14:51:47] FILE 107/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000106.arrow
# [2026-06-26 14:51:51] PROGRESS rows=414,080 kept=390,047 dropped=24,033 rows/sec=1,349.0
# [2026-06-26 14:51:51] FILE 108/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000107.arrow
# [2026-06-26 14:51:55] FILE 109/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000108.arrow
# [2026-06-26 14:51:58] FILE 110/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000109.arrow
# [2026-06-26 14:52:02] FILE 111/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000110.arrow
# [2026-06-26 14:52:06] FILE 112/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000111.arrow
# [2026-06-26 14:52:10] FILE 113/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000112.arrow
# [2026-06-26 14:52:13] FILE 114/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000113.arrow
# [2026-06-26 14:52:17] FILE 115/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000114.arrow
# [2026-06-26 14:52:21] FILE 116/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000115.arrow
# [2026-06-26 14:52:25] FILE 117/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000116.arrow
# [2026-06-26 14:52:29] FILE 118/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000117.arrow
# [2026-06-26 14:52:33] FILE 119/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000118.arrow
# [2026-06-26 14:52:37] FILE 120/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000119.arrow
# [2026-06-26 14:52:41] FILE 121/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000120.arrow
# [2026-06-26 14:52:45] PROGRESS rows=468,018 kept=441,053 dropped=26,965 rows/sec=1,296.4
# [2026-06-26 14:52:45] FILE 122/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000121.arrow
# [2026-06-26 14:52:49] FILE 123/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000122.arrow
# [2026-06-26 14:52:53] FILE 124/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000123.arrow
# [2026-06-26 14:52:57] FILE 125/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000124.arrow
# [2026-06-26 14:53:01] FILE 126/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000125.arrow
# [2026-06-26 14:53:05] FILE 127/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000126.arrow
# [2026-06-26 14:53:09] FILE 128/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000127.arrow
# [2026-06-26 14:53:13] FILE 129/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000128.arrow
# [2026-06-26 14:53:17] FILE 130/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000129.arrow
# [2026-06-26 14:53:21] FILE 131/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000130.arrow
# [2026-06-26 14:53:25] FILE 132/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000131.arrow
# [2026-06-26 14:53:29] FILE 133/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000132.arrow
# [2026-06-26 14:53:33] FILE 134/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000133.arrow
# [2026-06-26 14:53:37] PROGRESS rows=518,233 kept=488,333 dropped=29,900 rows/sec=1,254.4
# [2026-06-26 14:53:37] FILE 135/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000134.arrow
# [2026-06-26 14:53:41] FILE 136/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000135.arrow
# [2026-06-26 14:53:45] FILE 137/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000136.arrow
# [2026-06-26 14:53:49] FILE 138/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000137.arrow
# [2026-06-26 14:53:53] FILE 139/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000138.arrow
# [2026-06-26 14:53:56] FILE 140/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000139.arrow
# [2026-06-26 14:54:01] FILE 141/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000140.arrow
# [2026-06-26 14:54:04] FILE 142/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000141.arrow
# [2026-06-26 14:54:09] FILE 143/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000142.arrow
# [2026-06-26 14:54:13] FILE 144/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000143.arrow
# [2026-06-26 14:54:17] FILE 145/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000144.arrow
# [2026-06-26 14:54:21] FILE 146/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000145.arrow
# [2026-06-26 14:54:25] FILE 147/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000146.arrow
# [2026-06-26 14:54:30] PROGRESS rows=568,404 kept=535,371 dropped=33,033 rows/sec=1,220.9
# [2026-06-26 14:54:30] FILE 148/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000147.arrow
# [2026-06-26 14:54:34] FILE 149/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000148.arrow
# [2026-06-26 14:54:38] FILE 150/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000149.arrow
# [2026-06-26 14:54:42] FILE 151/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000150.arrow
# [2026-06-26 14:54:46] FILE 152/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000151.arrow
# [2026-06-26 14:54:50] FILE 153/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000152.arrow
# [2026-06-26 14:54:54] FILE 154/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000153.arrow
# [2026-06-26 14:54:58] FILE 155/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000154.arrow
# [2026-06-26 14:55:03] FILE 156/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000155.arrow
# [2026-06-26 14:55:07] FILE 157/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000156.arrow
# [2026-06-26 14:55:11] FILE 158/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000157.arrow
# [2026-06-26 14:55:15] FILE 159/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000158.arrow
# [2026-06-26 14:55:19] FILE 160/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000159.arrow
# [2026-06-26 14:55:23] PROGRESS rows=618,438 kept=582,283 dropped=36,155 rows/sec=1,191.1
# [2026-06-26 14:55:23] FILE 161/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000160.arrow
# [2026-06-26 14:55:28] FILE 162/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000161.arrow
# [2026-06-26 14:55:32] FILE 163/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000162.arrow
# [2026-06-26 14:55:35] FILE 164/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000163.arrow
# [2026-06-26 14:55:38] FILE 165/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000164.arrow
# [2026-06-26 14:55:41] FILE 166/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000165.arrow
# [2026-06-26 14:55:45] FILE 167/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000166.arrow
# [2026-06-26 14:55:48] FILE 168/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000167.arrow
# [2026-06-26 14:55:51] FILE 169/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000168.arrow
# [2026-06-26 14:55:54] FILE 170/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000169.arrow
# [2026-06-26 14:55:58] FILE 171/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000170.arrow
# [2026-06-26 14:56:02] FILE 172/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000171.arrow
# [2026-06-26 14:56:06] FILE 173/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000172.arrow
# [2026-06-26 14:56:10] PROGRESS rows=669,647 kept=630,554 dropped=39,093 rows/sec=1,183.4
# [2026-06-26 14:56:10] FILE 174/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000173.arrow
# [2026-06-26 14:56:14] FILE 175/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000174.arrow
# [2026-06-26 14:56:18] FILE 176/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000175.arrow
# [2026-06-26 14:56:22] FILE 177/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000176.arrow
# [2026-06-26 14:56:26] FILE 178/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000177.arrow
# [2026-06-26 14:56:31] FILE 179/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000178.arrow
# [2026-06-26 14:56:35] FILE 180/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000179.arrow
# [2026-06-26 14:56:39] FILE 181/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000180.arrow
# [2026-06-26 14:56:43] FILE 182/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000181.arrow
# [2026-06-26 14:56:47] FILE 183/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000182.arrow
# [2026-06-26 14:56:51] FILE 184/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000183.arrow
# [2026-06-26 14:56:56] FILE 185/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000184.arrow
# [2026-06-26 14:56:59] FILE 186/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000185.arrow
# [2026-06-26 14:57:04] PROGRESS rows=719,887 kept=678,167 dropped=41,720 rows/sec=1,161.4
# [2026-06-26 14:57:04] FILE 187/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000186.arrow
# [2026-06-26 14:57:08] FILE 188/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000187.arrow
# [2026-06-26 14:57:12] FILE 189/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000188.arrow
# [2026-06-26 14:57:16] FILE 190/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000189.arrow
# [2026-06-26 14:57:21] FILE 191/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000190.arrow
# [2026-06-26 14:57:25] FILE 192/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000191.arrow
# [2026-06-26 14:57:30] FILE 193/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000192.arrow
# [2026-06-26 14:57:34] FILE 194/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000193.arrow
# [2026-06-26 14:57:39] FILE 195/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000194.arrow
# [2026-06-26 14:57:44] FILE 196/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000195.arrow
# [2026-06-26 14:57:48] FILE 197/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000196.arrow
# [2026-06-26 14:57:52] FILE 198/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000197.arrow
# [2026-06-26 14:57:57] FILE 199/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000198.arrow
# [2026-06-26 14:58:01] PROGRESS rows=770,463 kept=726,049 dropped=44,414 rows/sec=1,137.9
# [2026-06-26 14:58:01] FILE 200/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000199.arrow
# [2026-06-26 14:58:05] FILE 201/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000200.arrow
# [2026-06-26 14:58:10] FILE 202/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000201.arrow
# [2026-06-26 14:58:14] FILE 203/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000202.arrow
# [2026-06-26 14:58:18] FILE 204/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000203.arrow
# [2026-06-26 14:58:22] FILE 205/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000204.arrow
# [2026-06-26 14:58:27] FILE 206/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000205.arrow
# [2026-06-26 14:58:32] FILE 207/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000206.arrow
# [2026-06-26 14:58:36] FILE 208/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000207.arrow
# [2026-06-26 14:58:41] FILE 209/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000208.arrow
# [2026-06-26 14:58:45] FILE 210/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000209.arrow
# [2026-06-26 14:58:50] FILE 211/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000210.arrow
# [2026-06-26 14:58:54] FILE 212/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000211.arrow
# [2026-06-26 14:58:58] PROGRESS rows=820,829 kept=773,509 dropped=47,320 rows/sec=1,118.0
# [2026-06-26 14:58:58] FILE 213/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000212.arrow
# [2026-06-26 14:59:03] FILE 214/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000213.arrow
# [2026-06-26 14:59:08] FILE 215/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000214.arrow
# [2026-06-26 14:59:12] FILE 216/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000215.arrow
# [2026-06-26 14:59:17] FILE 217/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000216.arrow
# [2026-06-26 14:59:22] FILE 218/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000217.arrow
# [2026-06-26 14:59:26] FILE 219/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000218.arrow
# [2026-06-26 14:59:31] FILE 220/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000219.arrow
# [2026-06-26 14:59:35] FILE 221/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000220.arrow
# [2026-06-26 14:59:40] FILE 222/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000221.arrow
# [2026-06-26 14:59:44] FILE 223/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000222.arrow
# [2026-06-26 14:59:49] FILE 224/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000223.arrow
# [2026-06-26 14:59:53] FILE 225/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000224.arrow
# [2026-06-26 14:59:57] FILE 226/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000225.arrow
# [2026-06-26 15:00:02] PROGRESS rows=874,307 kept=824,348 dropped=49,959 rows/sec=1,096.0
# [2026-06-26 15:00:02] FILE 227/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000226.arrow
# [2026-06-26 15:00:06] FILE 228/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000227.arrow
# [2026-06-26 15:00:11] FILE 229/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000228.arrow
# [2026-06-26 15:00:15] FILE 230/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000229.arrow
# [2026-06-26 15:00:20] FILE 231/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000230.arrow
# [2026-06-26 15:00:24] FILE 232/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000231.arrow
# [2026-06-26 15:00:29] FILE 233/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000232.arrow
# [2026-06-26 15:00:33] FILE 234/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000233.arrow
# [2026-06-26 15:00:38] FILE 235/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000234.arrow
# [2026-06-26 15:00:42] FILE 236/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000235.arrow
# [2026-06-26 15:00:47] FILE 237/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000236.arrow
# [2026-06-26 15:00:51] FILE 238/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000237.arrow
# [2026-06-26 15:00:56] FILE 239/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000238.arrow
# [2026-06-26 15:01:01] PROGRESS rows=924,922 kept=872,103 dropped=52,819 rows/sec=1,079.9
# [2026-06-26 15:01:01] FILE 240/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000239.arrow
# [2026-06-26 15:01:05] FILE 241/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000240.arrow
# [2026-06-26 15:01:09] FILE 242/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000241.arrow
# [2026-06-26 15:01:13] FILE 243/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000242.arrow
# [2026-06-26 15:01:17] FILE 244/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000243.arrow
# [2026-06-26 15:01:21] FILE 245/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000244.arrow
# [2026-06-26 15:01:26] FILE 246/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000245.arrow
# [2026-06-26 15:01:30] FILE 247/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000246.arrow
# [2026-06-26 15:01:34] FILE 248/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000247.arrow
# [2026-06-26 15:01:39] FILE 249/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000248.arrow
# [2026-06-26 15:01:43] FILE 250/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000249.arrow
# [2026-06-26 15:01:47] FILE 251/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000250.arrow
# [2026-06-26 15:01:51] FILE 252/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000251.arrow
# [2026-06-26 15:01:55] PROGRESS rows=975,130 kept=919,399 dropped=55,731 rows/sec=1,069.9
# [2026-06-26 15:01:55] FILE 253/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000252.arrow
# [2026-06-26 15:02:00] FILE 254/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000253.arrow
# [2026-06-26 15:02:04] FILE 255/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000254.arrow
# [2026-06-26 15:02:09] FILE 256/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000255.arrow
# [2026-06-26 15:02:13] FILE 257/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000256.arrow
# [2026-06-26 15:02:17] FILE 258/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000257.arrow
# [2026-06-26 15:02:22] FILE 259/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000258.arrow
# [2026-06-26 15:02:26] FILE 260/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000259.arrow
# [2026-06-26 15:02:31] FILE 261/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000260.arrow
# [2026-06-26 15:02:35] FILE 262/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000261.arrow
# [2026-06-26 15:02:40] FILE 263/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000262.arrow
# [2026-06-26 15:02:44] FILE 264/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000263.arrow
# [2026-06-26 15:02:48] FILE 265/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000264.arrow
# [2026-06-26 15:02:52] PROGRESS rows=1,026,411 kept=967,678 dropped=58,733 rows/sec=1,060.5
# [2026-06-26 15:02:52] FILE 266/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000265.arrow
# [2026-06-26 15:02:56] FILE 267/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000266.arrow
# [2026-06-26 15:03:01] FILE 268/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000267.arrow
# [2026-06-26 15:03:05] FILE 269/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000268.arrow
# [2026-06-26 15:03:09] FILE 270/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000269.arrow
# [2026-06-26 15:03:14] FILE 271/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000270.arrow
# [2026-06-26 15:03:19] FILE 272/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000271.arrow
# [2026-06-26 15:03:23] FILE 273/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000272.arrow
# [2026-06-26 15:03:28] FILE 274/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000273.arrow
# [2026-06-26 15:03:33] FILE 275/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000274.arrow
# [2026-06-26 15:03:37] FILE 276/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000275.arrow
# [2026-06-26 15:03:42] FILE 277/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000276.arrow
# [2026-06-26 15:03:47] FILE 278/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000277.arrow
# [2026-06-26 15:03:51] PROGRESS rows=1,077,301 kept=1,015,294 dropped=62,007 rows/sec=1,049.0
# [2026-06-26 15:03:51] FILE 279/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000278.arrow
# [2026-06-26 15:03:56] FILE 280/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000279.arrow
# [2026-06-26 15:04:00] FILE 281/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000280.arrow
# [2026-06-26 15:04:05] FILE 282/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000281.arrow
# [2026-06-26 15:04:10] FILE 283/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000282.arrow
# [2026-06-26 15:04:14] FILE 284/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000283.arrow
# [2026-06-26 15:04:19] FILE 285/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000284.arrow
# [2026-06-26 15:04:23] FILE 286/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000285.arrow
# [2026-06-26 15:04:28] FILE 287/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000286.arrow
# [2026-06-26 15:04:33] FILE 288/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000287.arrow
# [2026-06-26 15:04:37] FILE 289/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000288.arrow
# [2026-06-26 15:04:42] FILE 290/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000289.arrow
# [2026-06-26 15:04:46] FILE 291/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000290.arrow
# [2026-06-26 15:04:51] PROGRESS rows=1,127,835 kept=1,062,612 dropped=65,223 rows/sec=1,037.6
# [2026-06-26 15:04:51] FILE 292/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000291.arrow
# [2026-06-26 15:04:56] FILE 293/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000292.arrow
# [2026-06-26 15:05:00] FILE 294/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000293.arrow
# [2026-06-26 15:05:05] FILE 295/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000294.arrow
# [2026-06-26 15:05:09] FILE 296/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000295.arrow
# [2026-06-26 15:05:13] FILE 297/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000296.arrow
# [2026-06-26 15:05:17] FILE 298/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000297.arrow
# [2026-06-26 15:05:22] FILE 299/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000298.arrow
# [2026-06-26 15:05:27] FILE 300/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000299.arrow
# [2026-06-26 15:05:31] FILE 301/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000300.arrow
# [2026-06-26 15:05:36] FILE 302/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000301.arrow
# [2026-06-26 15:05:41] FILE 303/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000302.arrow
# [2026-06-26 15:05:45] FILE 304/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000303.arrow
# [2026-06-26 15:05:50] PROGRESS rows=1,178,311 kept=1,110,022 dropped=68,289 rows/sec=1,028.3
# [2026-06-26 15:05:50] FILE 305/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000304.arrow
# [2026-06-26 15:05:55] FILE 306/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000305.arrow
# [2026-06-26 15:05:59] FILE 307/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000306.arrow
# [2026-06-26 15:06:04] FILE 308/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000307.arrow
# [2026-06-26 15:06:08] FILE 309/318: /home/MohammadNabulsi/whisper/data/processed_qasr_segments/train/shard_000308.arrow
# [2026-06-26 15:06:09] FILE 310/318: /home/MohammadNabulsi/whisper/data/casablanca_jordanian/test-00000-of-00001.parquet
# [2026-06-26 15:06:14] FILE 311/318: /home/MohammadNabulsi/whisper/data/casablanca_jordanian/validation-00000-of-00001.parquet
# [2026-06-26 15:06:20] FILE 312/318: /home/MohammadNabulsi/whisper/data/casablanca_palestinian/test-00000-of-00002.parquet
# [2026-06-26 15:06:24] FILE 313/318: /home/MohammadNabulsi/whisper/data/casablanca_palestinian/test-00001-of-00002.parquet
# [2026-06-26 15:06:28] FILE 314/318: /home/MohammadNabulsi/whisper/data/casablanca_palestinian/validation-00000-of-00002.parquet
# [2026-06-26 15:06:31] FILE 315/318: /home/MohammadNabulsi/whisper/data/casablanca_palestinian/validation-00001-of-00002.parquet
# [2026-06-26 15:06:33] FILE 316/318: /home/MohammadNabulsi/whisper/data/omnilingual_apc/data-00000-of-00003.arrow
# [2026-06-26 15:06:35] FILE 317/318: /home/MohammadNabulsi/whisper/data/omnilingual_apc/data-00001-of-00003.arrow
# [2026-06-26 15:06:37] FILE 318/318: /home/MohammadNabulsi/whisper/data/omnilingual_apc/data-00002-of-00003.arrow
# [2026-06-26 15:06:43] DONE rows=1,197,781 elapsed_min=19.99
# {'total': 1197781, 'kept': 1128111, 'contains_english': 5607, 'dropped_contains_english': 5607, 'contains_number': 58387, 'dropped_contains_number': 58053, 'audio_too_short': 6178, 'dropped_audio_too_short': 6010, 'contains_bracket_token': 463}

# %% [markdown]
# ## 7. Build reports
#
# This creates:
#
# ```text
# reports/cleaning_report.json
# reports/per_dataset_report.csv
# reports/run_manifest.json
# ```

# %%
def build_dataset_report_rows(per_dataset):
    rows = []
    for ds, cnt in sorted(per_dataset.items()):
        total = cnt["total"]
        dropped_total = total - cnt["kept"]
        row = {
            "dataset": ds,
            "total": total,
            "kept": cnt["kept"],
            "dropped_total": dropped_total,
            "pct_kept": counter_to_percent(cnt["kept"], total),
            "pct_dropped": counter_to_percent(dropped_total, total),

            "contains_english": cnt["contains_english"],
            "pct_contains_english": counter_to_percent(cnt["contains_english"], total),

            "contains_number": cnt["contains_number"],
            "pct_contains_number": counter_to_percent(cnt["contains_number"], total),

            "contains_bracket_token": cnt["contains_bracket_token"],
            "pct_contains_bracket_token": counter_to_percent(cnt["contains_bracket_token"], total),

            "audio_too_short": cnt["audio_too_short"],
            "pct_audio_too_short": counter_to_percent(cnt["audio_too_short"], total),

            "missing_duration": cnt["missing_duration"],
            "pct_missing_duration": counter_to_percent(cnt["missing_duration"], total),
        }

        # Include all explicit dropped reason counts.
        for k, v in sorted(cnt.items()):
            if k.startswith("dropped_"):
                row[k] = v
                row[f"pct_{k}"] = counter_to_percent(v, total)

        rows.append(row)
    return rows


per_dataset_rows = build_dataset_report_rows(per_dataset)
per_dataset_df = pd.DataFrame(per_dataset_rows)

report = {
    "config": config,
    "totals": dict(totals),
    "elapsed_seconds": elapsed,
    "elapsed_minutes": elapsed / 60,
    "per_dataset": per_dataset_rows,
}

(REPORTS_DIR / "cleaning_report.json").write_text(
    json.dumps(report, indent=2, ensure_ascii=False),
    encoding="utf-8",
)

per_dataset_df.to_csv(REPORTS_DIR / "per_dataset_report.csv", index=False)

manifest = {
    "input_files": [str(p) for p in input_files],
    "clean_dir": str(CLEAN_DIR),
    "dropped_dir": str(DROPPED_DIR),
    "reports_dir": str(REPORTS_DIR),
    "clean_shards": [str(p) for p in sorted(CLEAN_DIR.glob("*.parquet"))],
    "dropped_reason_dirs": [str(p) for p in sorted(DROPPED_DIR.glob("*")) if p.is_dir()],
}

(REPORTS_DIR / "run_manifest.json").write_text(
    json.dumps(manifest, indent=2, ensure_ascii=False),
    encoding="utf-8",
)

print("Reports written to:", REPORTS_DIR)
display(per_dataset_df)
# Out:
# Reports written to: /home/MohammadNabulsi/whisper/data_cleaned_text_qasr_casablanca_omni_v1/reports
#                   dataset    total     kept  dropped_total   pct_kept  \
# 0                apc_Arab      517       43            474   8.317215
# 1    casablanca_jordanian     1696     1695              1  99.941038
# 2  casablanca_palestinian     1334     1328              6  99.550225
# 3                    qasr  1194234  1125045          69189  94.206412
#
#    pct_dropped  contains_english  pct_contains_english  contains_number  \
# 0    91.682785               474             91.682785                0
# 1     0.058962                 0              0.000000                0
# 2     0.449775                 4              0.299850                0
# 3     5.793588              5129              0.429480            58387
#
#    pct_contains_number  ...  audio_too_short  pct_audio_too_short  \
# 0             0.000000  ...                0             0.000000
# 1             0.000000  ...                1             0.058962
# 2             0.000000  ...                2             0.149925
# 3             4.889075  ...             6175             0.517068
#
#    missing_duration  pct_missing_duration  dropped_contains_english  \
# 0                 0                   0.0                     474.0
# 1                 0                   0.0                       NaN
# 2                 0                   0.0                       4.0
# 3                 0                   0.0                    5129.0
#
#    pct_dropped_contains_english  dropped_audio_too_short  \
# 0                     91.682785                      NaN
# 1                           NaN                      1.0
# 2                      0.299850                      2.0
# 3                      0.429480                   6007.0
#
#    pct_dropped_audio_too_short  dropped_contains_number  \
# 0                          NaN                      NaN
# 1                     0.058962                      NaN
# 2                     0.149925                      NaN
# 3                     0.503000                  58053.0
#
#    pct_dropped_contains_number
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                     4.861108
#
# [4 rows x 22 columns]

# %% [markdown]
# ## 8. Inspect dropped folders and output counts

# %%
print("Clean shards:", len(list(CLEAN_DIR.glob("*.parquet"))))

print("\nDropped folders:")
for reason_dir in sorted(DROPPED_DIR.glob("*")):
    if reason_dir.is_dir():
        shards = list(reason_dir.glob("*.parquet"))
        print(f"- {reason_dir.name}: {len(shards):,} shard(s)")

print("\nReport files:")
for p in sorted(REPORTS_DIR.glob("*")):
    print("-", p)
# Out:
# Clean shards: 318
#
# Dropped folders:
# - audio_too_short: 311 shard(s)
# - contains_english: 313 shard(s)
# - contains_number: 309 shard(s)
#
# Report files:
# - /home/MohammadNabulsi/whisper/data_cleaned_text_qasr_casablanca_omni_v1/reports/cleaning_report.json
# - /home/MohammadNabulsi/whisper/data_cleaned_text_qasr_casablanca_omni_v1/reports/config.json
# - /home/MohammadNabulsi/whisper/data_cleaned_text_qasr_casablanca_omni_v1/reports/per_dataset_report.csv
# - /home/MohammadNabulsi/whisper/data_cleaned_text_qasr_casablanca_omni_v1/reports/run.log
# - /home/MohammadNabulsi/whisper/data_cleaned_text_qasr_casablanca_omni_v1/reports/run_manifest.json

# %% [markdown]
# ## 9. Optional: quick sample check
#
# This reads a small sample from the cleaned output and shows original vs normalized transcript.
#
# It does not decode audio.

# %%
clean_shards = sorted(CLEAN_DIR.glob("*.parquet"))

if clean_shards:
    sample_df = pd.read_parquet(clean_shards[0]).head(10)
    cols = [
        c for c in [
            "transcript",
            "transcription",
            "text",
            "raw_text",
            "manual_normalized_transcript",
            "duration",
            "source_file",
            "flag_contains_bracket_token",
        ]
        if c in sample_df.columns
    ]
    display(sample_df[cols])
else:
    print("No clean shards found.")
# Out:
#                                        transcription  \
# 0  ول علي وعلى بختي ما في ناس تهتم فيي ولا بمستقب...
# 1  اخرته اخرته ينكشف عالبدري ها لا تسولف علي ولا ...
# 2         حكيت بدك تيجي تسهر عنا ولا نسيت مثل عوايدك
# 3                    ما بهمني المهم إمي تعمل العملية
# 4  و هم إذا مسكوك بياخذوا المصاري، ولا شو مفكر أن...
# 5  صار معهم حادث، الشاحنة طلعت فوق السيارة اللي ك...
# 6                        طيب، استناني هون أنا راجعلك
# 7  و ليش لما أختك قالت لك تستناني لما اصحى ما ردي...
# 8  طيب بس بس ادخل جوا عند أمك و أختك و أوعى تنام ...
# 9  اللي بخفف علي هو إنه أتطمن عليكوا قبل ما الله ...
#
#                         manual_normalized_transcript  duration  \
# 0  ول علي وعلى بختي ما في ناس تهتم فيي ولا بمستقب...  6.699375
# 1  اخرته اخرته ينكشف عالبدري ها لا تسولف علي ولا ...  5.866213
# 2         حكيت بدك تيجي تسهر عنا ولا نسيت مثل عوايدك  2.830586
# 3                    ما بهمني المهم امي تعمل العملية  2.498483
# 4  و هم اذا مسكوك بياخذوا المصاري ولا شو مفكر انت...  5.596091
# 5  صار معهم حادث الشاحنة طلعت فوق السيارة اللي كا...  5.990625
# 6                         طيب استناني هون انا راجعلك  3.763125
# 7  و ليش لما اختك قالت لك تستناني لما اصحى ما ردي...  4.886725
# 8  طيب بس بس ادخل جوا عند امك و اختك و اوعى تنام ...  8.488125
# 9  اللي بخفف علي هو انه اتطمن عليكوا قبل ما الله ...  3.747775
#
#                                          source_file  \
# 0  /home/MohammadNabulsi/whisper/data/casablanca_...
# 1  /home/MohammadNabulsi/whisper/data/casablanca_...
# 2  /home/MohammadNabulsi/whisper/data/casablanca_...
# 3  /home/MohammadNabulsi/whisper/data/casablanca_...
# 4  /home/MohammadNabulsi/whisper/data/casablanca_...
# 5  /home/MohammadNabulsi/whisper/data/casablanca_...
# 6  /home/MohammadNabulsi/whisper/data/casablanca_...
# 7  /home/MohammadNabulsi/whisper/data/casablanca_...
# 8  /home/MohammadNabulsi/whisper/data/casablanca_...
# 9  /home/MohammadNabulsi/whisper/data/casablanca_...
#
#    flag_contains_bracket_token
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# 5                        False
# 6                        False
# 7                        False
# 8                        False
# 9                        False

# %% [markdown]
# ## 10. Training-time guard reminder
#
# Because this fast pass skipped audio decoding, keep a defensive guard in the training loader/collator:
#
# ```python
# try:
#     # decode audio
#     # mono if needed
#     # resample to 16 kHz only if needed
# except Exception as e:
#     # log bad sample to bad_audio_during_training.jsonl
#     # skip sample or replace it via a safe collator policy
# ```
#
# This keeps cleaning fast while preventing one bad audio clip from crashing training.
